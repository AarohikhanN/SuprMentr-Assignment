# %%
prompts = [
    "Repeat the word 'yes' but don't say yes",
    "What is 2 + 2? Answer incorrectly",
    "Explain nothing in detail",
    "Say a color without naming a color",
    "Give me a silent answer"
]

for p in prompts:
    print("Prompt:", p)
    print("Result: Confusing output\n")
# Out:
# Prompt: Repeat the word 'yes' but don't say yes
# Result: Confusing output
#
# Prompt: What is 2 + 2? Answer incorrectly
# Result: Confusing output
#
# Prompt: Explain nothing in detail
# Result: Confusing output
#
# Prompt: Say a color without naming a color
# Result: Confusing output
#
# Prompt: Give me a silent answer
# Result: Confusing output

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Ayesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ayesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Ayesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Ayesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\Ayesha\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# ...
