# %%
import pandas as pd

data = pd.read_csv("Groceries_dataset.csv")

print("Top 5 Rows of Dataset:")
print(data.head())

# Only numeric columns (if any)
numeric_data = data.select_dtypes(include='number')

if not numeric_data.empty:
    highest_column = numeric_data.max().idxmax()
    highest_value = numeric_data.max().max()

    print("\nColumn with Highest Value:", highest_column)
    print("Highest Value:", highest_value)
else:
    print("\nNo numeric columns found for max calculation.")

print("\nMissing Values in Each Column:")
print(data.isnull().sum())
# Out:
# Top 5 Rows of Dataset:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk
#
# Column with Highest Value: Member_number
# Highest Value: 5000
#
# Missing Values in Each Column:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64
