# %%
# Student Data Manager

students = {}

# Input data for 5 students
for i in range(5):
    name = input("Enter student name: ")
    marks = float(input("Enter marks: "))
    students[name] = marks

# Finding topper
topper = max(students, key=students.get)
top_marks = students[topper]

# Calculating class average
average = sum(students.values()) / len(students)

# Assigning grades
print("\nStudent Grades:")
for name, marks in students.items():
    if marks >= 90:
        grade = "A"
    elif marks >= 75:
        grade = "B"
    elif marks >= 60:
        grade = "C"
    else:
        grade = "D"
    
    print(name, ":", marks, "- Grade", grade)

# Display topper and average
print("\nTopper of the class:", topper, "with", top_marks, "marks")
print("Class Average:", average)
# Out:
# Enter student name:  Ayesha
# Enter marks:  78
# Enter student name:  Sheeba
# Enter marks:  89
# Enter student name:  Nisarga V
# Enter marks:  90
# Enter student name:  Honalu
# Enter marks:  98
# Enter student name:  Ameena
# Enter marks:  78
# Student Grades:
# Ayesha : 78.0 - Grade B
# Sheeba : 89.0 - Grade B
# Nisarga V  : 90.0 - Grade A
# Honalu : 98.0 - Grade A
# Ameena : 78.0 - Grade B
#
# Topper of the class: Honalu with 98.0 marks
# Class Average: 86.6
